# %%
import numpy as np
from sklearn.linear_model import Ridge, Lasso, LinearRegression

# %%
X = np.random.randn(100, 5)
y = 3*X[:,0] - 2*X[:,1] + 0.5*X[:,4] + np.random.randn(100)

# %%
lin = LinearRegression().fit(X, y)
ridge = Ridge(alpha=1.0).fit(X, y)
lasso = Lasso(alpha=0.1).fit(X, y)

# %%
print("Linear Regression:", lin.coef_)
print("Ridge:", ridge.coef_)
print("Lasso:", lasso.coef_)
# Out:
# Linear Regression: [ 2.95346265 -2.01542353  0.02269556 -0.06643641  0.61405932]
# Ridge: [ 2.93097053 -1.99202438  0.02383732 -0.0666988   0.60771982]
# Lasso: [ 2.88028663 -1.90102995  0.         -0.          0.49712204]
